# %% [markdown]
# <a href="https://colab.research.google.com/github/Shabrin1124/Hospital-Patient-Data-Analysis-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Patient data
data = {
    'Disease': ['Fever', 'Diabetes', 'Fever', 'Asthma', 'Diabetes', 'Fever'],
    'Age': [25, 45, 10, 35, 60, 30],
    'Month': ['Jan', 'Jan', 'Feb', 'Mar', 'Apr', 'Apr']
}

# Create DataFrame
df = pd.DataFrame(data)

# Disease count
print("Disease Count")
print(df['Disease'].value_counts())

# Age group count
print("\nAge Group Count")
print(df['Age'].apply(lambda x: 'Child' if x < 18 else 'Adult').value_counts())

# Peak admission month
print("\nAdmission Month Count")
print(df['Month'].value_counts())

# Disease graph
df['Disease'].value_counts().plot(kind='bar')
plt.title("Disease Wise Patient Count")
plt.xlabel("Disease")
plt.ylabel("Patients")
plt.show()
# Out:
# Disease Count
# Disease
# Fever       3
# Diabetes    2
# Asthma      1
# Name: count, dtype: int64
#
# Age Group Count
# Age
# Adult    5
# Child    1
# Name: count, dtype: int64
#
# Admission Month Count
# Month
# Jan    2
# Apr    2
# Feb    1
# Mar    1
# Name: count, dtype: int64
